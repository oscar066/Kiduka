# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# load the agrovet dataset
agro_df = pd.read_csv("data/agrovet_data.csv", delimiter='|')
agro_df.head(20)
# Out:
#     name                                   lat            lon           \
# 0   Nnnn                                      -1.511755      37.266900
# 1   Teso                                      -1.511964      37.266973
# 2   GOODWILL FAMERS AGROVET                    0.493122      34.133599
# 3   Farm Choice Agrovet                        0.473192      34.188131
# 4   Kemodo Agrovet                             0.467253      34.186033
# 5   Kkk                                       12.626639      34.168139
# 6   GEOIMA FARMERS SHOP                        0.494862      34.133243
# 7   AGROPHOS AGROVET                           0.492872      34.133403
# 8   SHILOH AGROVET                             0.536719      34.127506
# 9   KELMWA INVESTMENT                          0.517727      34.144275
# 10  Farm Land Mungatsi                         0.469205      34.315729
# 11  Silton                                     0.469205      34.316008
# ...

# %%
# Save the cleaned DataFrame to a new CSV file
# agro_df.to_csv("data/agrovet_data_cleaned.csv", sep=',', index=False)

# %%
agro_clean_df = pd.read_csv("data/agrovet_data_cleaned.csv", delimiter=',')
agro_clean_df.head(20)
# Out:
#     name                                   lat            lon           \
# 0   Nnnn                                      -1.511755      37.266900
# 1   Teso                                      -1.511964      37.266973
# 2   GOODWILL FAMERS AGROVET                    0.493122      34.133599
# 3   Farm Choice Agrovet                        0.473192      34.188131
# 4   Kemodo Agrovet                             0.467253      34.186033
# 5   Kkk                                       12.626639      34.168139
# 6   GEOIMA FARMERS SHOP                        0.494862      34.133243
# 7   AGROPHOS AGROVET                           0.492872      34.133403
# 8   SHILOH AGROVET                             0.536719      34.127506
# 9   KELMWA INVESTMENT                          0.517727      34.144275
# 10  Farm Land Mungatsi                         0.469205      34.315729
# 11  Silton                                     0.469205      34.316008
# ...

# %%
agro_clean_df.columns = agro_clean_df.columns.str.strip()
agro_clean_df.columns
# Out:
# Index(['name', 'lat', 'lon', 'products', 'prices'], dtype='object')

# %%
agro_clean_df["lat"].value_counts()
# Out:
# lat
#  0.452599     3
#  0.522072     2
#  0.469205     2
#  0.563298     2
#  0.334270     2
#  0.302576     2
#  0.606123     1
#  0.448878     1
#  0.460708     1
#  0.459707     1
#  0.456479     1
#  0.458668     1
#  78.296322    1
#  0.141457     1
#  65.844080    1
#  0.461643     1
# -6.912539     1
#  36.879617    1
#  0.455423     1
#  54.673830    1
#  0.595839     1
#  0.463745     1
#  0.472237     1
#  0.457070     1
#  0.458563     1
#  0.071220     1
#  0.458664     1
#  0.330022     1
#  0.458407     1
#  0.464452     1
#  0.347709     1
#  0.458832     1
#  0.590018     1
#  0.455027     1
#  0.451818     1
#  0.456737     1
#  0.184232     1
#  0.184326     1
#  0.565757     1
#  0.481546     1
#  0.454241     1
#  52.661519    1
#  0.532517     1
#  0.544632     1
#  0.565519     1
#  0.544642     1
#  0.556700     1
#  0.544686     1
#  0.544587     1
#  0.544628     1
#  0.337166     1
#  0.411390     1
#  0.627687     1
#  0.523154     1
#  0.544622     1
# ...

# %%
# Save the cleaned DataFrame to a new CSV file
agro_df.to_csv("data/agrovet_data_cleaned.csv", index=False)

# %%
# load the busia agrovet dataset
bs_agro_df = pd.read_csv("data/Busia_AgroDealers.csv")
bs_agro_df.head(20)
# Out:
#                                                                                                                                                                               county  \
# Busia    "{'county': 'Busia' 'subcounty': '' 'ward': ""Ageng'a Nanguba"" 'agrodealerName': 'Nnnn'                      'market': 'Bhhhu'                 'gpsLatitude': '-1.5117552'
#                                              'ward': 'Malaba North'      'agrodealerName': 'Teso'                      'market': 'Gotura'                'gpsLatitude': '-1.5119642'
#                                              'ward': ""Ang'orom""        'agrodealerName': 'GOODWILL FAMERS AGROVET'   'market': ""ANG'OROM""              'gpsLatitude': '0.493122'
#                                              'ward': 'Marachi North'     'agrodealerName': 'Mavuno bora'               'market': 'Butula'                          'gpsLatitude': ''
# ...

# %%
bs_agro_df.columns
# Out:
# Index(['county', ' subcounty', ' ward', ' dealers'], dtype='object')
