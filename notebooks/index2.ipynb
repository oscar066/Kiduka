# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the style for seaborn
sns.set(style="darkgrid")

# allow all columns to be displayed
pd.set_option('display.max_columns', None)

# %%
# read data from the cleaned sheet
df = pd.read_csv('/teamspace/uploads/output_data_points.csv', index_col=0)

# preview of the first 10 rows of the dataframe
df.head(20)
# Out:
#          lat        lon      property   original_name  upper_depth_cm  \
# id
# 1   0.493863  34.608559            Ca         Calcium               0
# 2   0.493863  34.608559            pH              pH               0
# 3   0.493863  34.608559            Mg       Magnesium               0
# 4   0.493863  34.608559             K  Exchangeable K               0
# 5   0.493863  34.608559  usda_texture    Soil Texture               0
# 6   0.493863  34.608559            OM  Organic Matter               0
# 7   0.493863  34.608559            CN       C/N ratio               0
# 8   0.493863  34.608559             N  Total Nitrogen               0
# 9   0.465259  34.602359            Ca         Calcium               0
# 10  0.465259  34.602359            pH              pH               0
# 11  0.465259  34.602359            Mg       Magnesium               0
# 12  0.465259  34.602359             K  Exchangeable K               0
# ...

# %%
df.shape
# Out:
# (160603, 13)

# %% [markdown]
# ### Pivoted Data

# %%
# Load the Pivoted data
df_clean = pd.read_csv('data/soil_data_pivoted.csv', index_col=0)

# preview of the first 10 rows of the cleaned dataframe
df_clean.head(10)
# Out:
#            lon        upper_depth_cm  lower_depth_cm  sampling_date  \
# lat
# -4.208266  39.449667               0              20           2024
# -2.619400  38.767136               0              20           2024
# -2.339255  36.817416               0              20           2024
# -1.743613  35.771623               0              20           2024
# -1.739673  35.767769               0              20           2024
# -1.729915  35.766988               0              20           2024
# -1.729339  35.767715               0              20           2024
# -1.714761  35.779384               0              20           2024
# -1.712410  35.777850               0              20           2024
# -1.709348  35.825769               0              20           2024
#
#             license                                        h3_index         \
# lat
# -4.208266   Data4SoilHealth Challenge Data Use Agreement   837b4afffffffff
# ...

# %%
df_clean.shape
# Out:
# (9454, 27)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9454 entries, -4.208266 to 3.47104
# Data columns (total 27 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    lon                                           9454 non-null   float64
#  1    upper_depth_cm                                9454 non-null   int64
#  2    lower_depth_cm                                9454 non-null   int64
#  3    sampling_date                                 9454 non-null   int64
#  4    license                                       9454 non-null   object
#  5    h3_index                                      9454 non-null   object
#  6    publication_date                              9454 non-null   object
#  7    data_source                                   9454 non-null   object
#  8    Al                                            9454 non-null   object
# ...

# %%
df_clean.isna().sum()
# Out:
# lon                                             0
# upper_depth_cm                                  0
# lower_depth_cm                                  0
# sampling_date                                   0
# license                                         0
# h3_index                                        0
# publication_date                                0
# data_source                                     0
# Al                                              0
# CEC                                             0
# CN                                              0
# Ca                                              0
# Cu                                              0
# Fe                                              0
# K                                               0
# Mg                                              0
# N                                               0
# OM                                              0
# P                                               0
# ...

# %%
# read data from the cleaned sheet
df = pd.read_excel('data/Soil Data Yara Kenya Maddo.xlsx', index_col=0)

# preview of the first 10 rows of the dataframe
df.head(20)
# Out:
#             lon         Al                    CEC                 \
# lat
# -4.208266   39.449667
# -2.619400   38.767136
# -2.339255   36.817416
# -1.743613   35.771623               49.1875                  375
# -1.739673   35.767769              50.90625                  470
# -1.729915   35.766988             21.703125                   97
# -1.729339   35.767715              21.59375                   70
# -1.714761   35.779384             11.398438                   54
# -1.712410   35.777850             13.796875                   38
# -1.709348   35.825769               40.8125                  111
# -1.709199   35.776486             17.203125                   64
# -1.707215   35.784863               32.6875                  118
# -1.701819   35.785771             16.796875                   45
# -1.697676   35.784201              21.09375                   86
# -1.696471   35.800599              22.40625                   87
# ...
