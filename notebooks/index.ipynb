# %% [markdown]
# ## Data Understanding

# %%
#!uv pip install openpyxl

# %%
# Importing the necessary libararies
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
# read data from the cleaned sheet
df_clean = pd.read_excel('../data/cleaned.xlsx', sheet_name='Sheet1')

# preview of the first 10 rows of the dataframe
df_clean.head(10)
# Out:
#   Simplied Texture (1)     pH     N     P     K     O   Ca   Mg   Cu    Fe  \
# 0           SILTY SOIL    4.9  0.14  22.9  0.14   1.1  1.3  2.2  1.2  10.1
# 1           LOAMY SOIL    5.7  0.14  28.3  0.27   1.3  1.8  2.1  1.2  12.9
# 2           SILTY LOAM    5.9  0.16  23.1  0.39   2.1  1.6  2.5  1.2  10.1
# 3           LOAMY SOIL    5.7  0.20  29.2  0.47   2.1  2.8  2.2  1.2  12.0
# 4                 LOAM    5.7  0.14  28.3  0.28   2.2  3.2  1.4  1.2  12.3
# 5           SILTY SAND    5.7  0.17  29.2  0.72   2.0  2.4  1.9  1.2  11.2
# 6                 SILT    5.9  0.18  27.2  0.18   1.9  2.7  2.0  1.4  13.1
# 7                 LOAM    5.7  0.16  22.9  1.22   1.2  2.2  1.5  1.7  12.4
# 8           LOAMY SILT    5.6  0.15  19.4  0.72   1.3  1.9  2.2  1.2  12.6
# 9                 LOAM    5.4  0.14  23.2  1.21   1.4  1.1  2.1  1.1  12.9
#
#      Zn Soil Fertility Status Crop Recommendation 1 Crop Recommendation 2  \
# 0   5.6             VERY POOR               CASSAVA                COTTON
# 1   5.2    MODERATELY HEALTHY                BANANA                  ALVS
# 2   6.4    MODERATELY HEALTHY                BANANA                  ALVS
# 3   7.4    MODERATELY HEALTHY                BANANA                  ALVS
# 4   7.0    MODERATELY HEALTHY                BANANA                  ALVS
# 5  10.3    MODERATELY HEALTHY               SOYBEAN                SESAME
# 6   5.9    MODERATELY HEALTHY                 BEANS                 MAIZE
# 7   9.4    MODERATELY HEALTHY                BANANA                  ALVS
# 8   8.7                  POOR                BANANA                  ALVS
# 9   6.8                  POOR                 MAIZE                 BEANS
#
#   Fertilizer Recommendation 1 Fertilizer Recommendation 2
# 0                         NPK                         NPK
# 1                         NPK                         NPK
# 2                         NPK                         NPK
# 3                         NPK                         NPK
# 4                         NPK                         NPK
# 5                         NPK                         NPK
# 6                         NPK                         TSP
# 7                         NPK                         NPK
# 8                         NPK                         NPK
# 9                         NPK                         TSP

# %%
# sample the dataset 
df_clean.sample(10)
# Out:
#     Simplied Texture (1)     pH     N     P     K     O    Ca   Mg   Cu    Fe  \
# 616           SILTY SOIL    5.5  0.14  22.1  0.27   1.7   1.8  2.1  1.2  12.9
# 396           LOAMY SILT    6.6  0.17  28.3  1.17   0.6   1.9  2.2  1.2  10.3
# 193                 LOAM    5.8  0.17  22.1  1.07   1.2  11.3  2.1  1.3  10.3
# 608           LOAMY SOIL    5.4  0.17  26.2  1.07   1.3   4.7  1.9  1.4  11.9
# 426           LOAMY SILT    5.7  0.15  22.2  1.22   1.8   4.9  1.5  1.7  12.4
# 667           SILTY SOIL    5.0  0.14  19.7  1.07   0.9   1.2  1.2  1.5  12.2
# 885           LOAMY SOIL    5.9  0.17  29.2  1.07  15.4   2.4  2.8  1.1  10.5
# 219                 LOAM    5.3  0.17  29.4  0.06   0.8   1.2  2.2  1.2  12.7
# 114           SANDY SILT    5.0  0.13  19.7  1.07   1.1   3.2  1.8  1.5  10.3
# 120                 SILT    6.2  0.23  30.6  1.07   1.2  11.2  2.1  1.3  10.3
#
#        Zn Soil Fertility Status Crop Recommendation 1 Crop Recommendation 2  \
# 616   5.9                  POOR                SESAME               SOYBEAN
# 396   4.3    MODERATELY HEALTHY                  ALVS                BANANA
# 193   7.4    MODERATELY HEALTHY             SUNFLOWER                MILLET
# 608   6.5                  POOR                SESAME               SOYBEAN
# 426   8.3    MODERATELY HEALTHY                 MAIZE                 BEANS
# 667   8.7             VERY POOR                SESAME               SOYBEAN
# 885   7.4    MODERATELY HEALTHY                MILLET               SORGHUM
# 219   3.9                  POOR                COTTON               CASSAVA
# 114  10.3             VERY POOR             PINEAPPLE                PEANUT
# 120   4.8    MODERATELY HEALTHY                  ALVS                BANANA
#
#     Fertilizer Recommendation 1 Fertilizer Recommendation 2
# 616                         NPK                         NPK
# 396                         NPK                         NPK
# 193                         NPK                         NPK
# 608                         NPK                         NPK
# 426                         NPK                         TSP
# 667                         NPK                         NPK
# 885                         NPK                         NPK
# 219                         NPK                         NPK
# 114                         NPK                         NPK
# 120                         NPK                         NPK

# %%
# Preview of the tail data
df_clean.tail(10)
# Out:
#     Simplied Texture (1)     pH     N     P     K     O   Ca   Mg   Cu    Fe  \
# 990           LOAMY SILT    5.5  0.15  19.8  1.07   0.8  1.7  1.0  1.5  11.2
# 991           LOAMY SOIL    5.7  0.14  19.7  0.72   0.3  1.0  1.2  1.5  11.9
# 992           LOAMY SOIL    5.1  0.14  19.8  0.09   0.7  0.9  2.2  1.3  11.2
# 993           LOAMY SAND    6.0  0.18  27.2  1.07   0.4  1.7  1.2  1.2  11.4
# 994           LOAMY SOIL    6.2  0.18  29.2  1.07   0.2  3.2  2.2  1.2  11.2
# 995           LOAMY SOIL    5.8  0.18  19.8  1.07   0.8  1.0  1.7  1.6  11.2
# 996           LOAMY SAND    5.7  0.18  28.6  1.07   0.4  0.8  2.1  1.5  11.9
# 997           LOAMY SILT    5.7  0.14  19.8  0.72   0.3  1.8  2.1  1.6  11.4
# 998           LOAMY SOIL    4.8  0.14  19.8  1.07   0.9  1.6  1.8  1.5  11.2
# 999           LOAMY SOIL    4.9  0.14  19.7  1.07   0.7  3.3  2.0  1.3  11.8
#
#        Zn Soil Fertility Status Crop Recommendation 1 Crop Recommendation 2  \
# 990   4.2                  POOR                COTTON               CASSAVA
# 991   3.9    MODERATELY HEALTHY               SOYBEAN                SESAME
# 992   4.3                  POOR                SESAME               SOYBEAN
# 993   9.4    MODERATELY HEALTHY                  ALVS                BANANA
# 994   8.3    MODERATELY HEALTHY                  ALVS                BANANA
# 995   6.3    MODERATELY HEALTHY             SUNFLOWER                MILLET
# 996   7.4    MODERATELY HEALTHY               SOYBEAN                SESAME
# 997   5.6    MODERATELY HEALTHY               SOYBEAN                SESAME
# 998   4.8             VERY POOR               CASSAVA                COTTON
# 999   4.9             VERY POOR               CASSAVA                COTTON
#
#     Fertilizer Recommendation 1 Fertilizer Recommendation 2
# 990                         NPK                         NPK
# 991                         NPK                         NPK
# 992                         NPK                         NPK
# 993                         NPK                         NPK
# 994                         NPK                         NPK
# 995                         NPK                         NPK
# 996                         NPK                         NPK
# 997                         NPK                         NPK
# 998                         NPK                         NPK
# 999                         NPK                         NPK

# %%
# Get the shape of the dataset
df_clean.shape
# Out:
# (1000, 16)

# %% [markdown]
# The dataset contains 1000 rows and 16 columns

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Simplied Texture (1)         1000 non-null   object
#  1      pH                        1000 non-null   float64
#  2    N                           1000 non-null   float64
#  3    P                           1000 non-null   float64
#  4    K                           1000 non-null   float64
#  5      O                         1000 non-null   float64
#  6    Ca                          1000 non-null   float64
#  7    Mg                          1000 non-null   float64
#  8    Cu                          1000 non-null   float64
#  9    Fe                          1000 non-null   float64
#  10    Zn                         1000 non-null   float64
#  11  Soil Fertility Status        1000 non-null   object
#  12  Crop Recommendation 1        1000 non-null   object
#  13  Crop Recommendation 2        1000 non-null   object
#  14  Fertilizer Recommendation 1  1000 non-null   object
#  15  Fertilizer Recommendation 2  1000 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 125.1+ KB

# %%
df_clean["Simplied Texture (1)"].value_counts()
# Out:
# Simplied Texture (1)
# LOAMY SOIL    495
# LOAM          135
# LOAMY SILT    133
# SILT           46
# SILTY SOIL     45
# LOAMY CLAY     27
# LOAMY SAND     24
# SANDY SILT     24
# SILTY LOAM     20
# CLAY SOIL      14
# SILTY SAND     13
# SANDY LOAM      6
# SANDY SOIL      5
# SILTY CLAY      3
# CLAY SILT       2
# LOAM SOIL       2
# SILT SAND       2
# CLAY LOAM       2
# SANDY           1
# LOAMY LOAM      1
# Name: count, dtype: int64

# %%
df_clean["Soil Fertility Status"].value_counts()
# Out:
# Soil Fertility Status
# MODERATELY HEALTHY    493
# POOR                  377
# VERY POOR             130
# Name: count, dtype: int64

# %%
# clean the crop columns:
df_clean["Crop Recommendation 1"].value_counts()
# Out:
# Crop Recommendation 1
# ALVS           176
# SESAME         175
# MAIZE          144
# COTTON         109
# CASSAVA         91
# SOYBEAN         76
# MILLET          42
# SORGHUM         37
# SUNFLOWER       36
# BEANS           36
# BANANA          28
# PEANUT          16
# BANANAS         11
# PINEAPPLE       10
# PAWPAW           6
# ARROW ROOTS      4
# SORGUM           2
#  MAIZE           1
# Name: count, dtype: int64

# %%
# Cleanup this crop recommendation data

# 1. Strip potential leading/trailing whitespace (fixes " MAIZE")
df_clean['Crop Recommendation 1'] = df_clean['Crop Recommendation 1'].str.strip()

# 2. Define replacements for typos and duplicates
cleanup_map = {
    'SORGUM': 'SORGHUM',
    'BANANAS': 'BANANA'
}

# 3. Apply the replacements
df_clean['Crop Recommendation 1'] = df_clean['Crop Recommendation 1'].replace(cleanup_map)

# Verify the results
df_clean['Crop Recommendation 1'].value_counts()
# Out:
# Crop Recommendation 1
# ALVS           176
# SESAME         175
# MAIZE          145
# COTTON         109
# CASSAVA         91
# SOYBEAN         76
# MILLET          42
# BANANA          39
# SORGHUM         39
# BEANS           36
# SUNFLOWER       36
# PEANUT          16
# PINEAPPLE       10
# PAWPAW           6
# ARROW ROOTS      4
# Name: count, dtype: int64

# %%
df_clean["Crop Recommendation 2"].value_counts()
# Out:
# Crop Recommendation 2
# SOYBEAN      174
# BANANA       167
# BEANS        145
# CASSAVA      113
# COTTON        91
# SESAME        76
# MILLET        75
# ALVS          45
# SORGHUM       43
# MAIZE         36
# PINEAPPLE     16
# PEANUT        10
# BANANAS        9
# Name: count, dtype: int64

# %%
# 1. Strip potential leading/trailing whitespace
df_clean['Crop Recommendation 2'] = df_clean['Crop Recommendation 2'].str.strip()

# 2. Replace 'BANANAS' with 'BANANA'
df_clean['Crop Recommendation 2'] = df_clean['Crop Recommendation 2'].replace({'BANANAS': 'BANANA'})

# Verify the results
df_clean['Crop Recommendation 2'].value_counts()
# Out:
# Crop Recommendation 2
# BANANA       176
# SOYBEAN      174
# BEANS        145
# CASSAVA      113
# COTTON        91
# SESAME        76
# MILLET        75
# ALVS          45
# SORGHUM       43
# MAIZE         36
# PINEAPPLE     16
# PEANUT        10
# Name: count, dtype: int64

# %% [markdown]
# ### Data Cleaning and Wrangling

# %% [markdown]
# #### 1. Checking for completeness

# %%
# checking for missing values
df_clean.isna().sum()
# Out:
# Simplied Texture (1)           0
#    pH                          0
#  N                             0
#  P                             0
#  K                             0
#    O                           0
#  Ca                            0
#  Mg                            0
#  Cu                            0
#  Fe                            0
#   Zn                           0
# Soil Fertility Status          0
# Crop Recommendation 1          0
# Crop Recommendation 2          0
# Fertilizer Recommendation 1    0
# Fertilizer Recommendation 2    0
# dtype: int64

# %% [markdown]
# The dataset contains no missing values

# %% [markdown]
# #### 2. Checking for Consistency

# %%
# checking for duplicated values
df_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The dataset contains no duplicated values

# %% [markdown]
# #### 3. Checking for Uniformity

# %%
# Before converting objects to categorical
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Simplied Texture (1)         1000 non-null   object
#  1      pH                        1000 non-null   float64
#  2    N                           1000 non-null   float64
#  3    P                           1000 non-null   float64
#  4    K                           1000 non-null   float64
#  5      O                         1000 non-null   float64
#  6    Ca                          1000 non-null   float64
#  7    Mg                          1000 non-null   float64
#  8    Cu                          1000 non-null   float64
#  9    Fe                          1000 non-null   float64
#  10    Zn                         1000 non-null   float64
#  11  Soil Fertility Status        1000 non-null   object
#  12  Crop Recommendation 1        1000 non-null   object
#  13  Crop Recommendation 2        1000 non-null   object
#  14  Fertilizer Recommendation 1  1000 non-null   object
#  15  Fertilizer Recommendation 2  1000 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 125.1+ KB

# %%
# Function to convert object columns to categorical
def convert_objects_to_categorical(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].astype('category')
    return df

# Convert object columns to categorical
df_clean = convert_objects_to_categorical(df_clean)

# %%
# Checking the data types after conversion
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Simplied Texture (1)         1000 non-null   category
#  1      pH                        1000 non-null   float64
#  2    N                           1000 non-null   float64
#  3    P                           1000 non-null   float64
#  4    K                           1000 non-null   float64
#  5      O                         1000 non-null   float64
#  6    Ca                          1000 non-null   float64
#  7    Mg                          1000 non-null   float64
#  8    Cu                          1000 non-null   float64
#  9    Fe                          1000 non-null   float64
#  10    Zn                         1000 non-null   float64
#  11  Soil Fertility Status        1000 non-null   category
#  12  Crop Recommendation 1        1000 non-null   category
#  13  Crop Recommendation 2        1000 non-null   category
#  14  Fertilizer Recommendation 1  1000 non-null   category
#  15  Fertilizer Recommendation 2  1000 non-null   category
# dtypes: category(6), float64(10)
# memory usage: 86.2 KB

# %%
df_clean.columns
# Out:
# Index(['Simplied Texture (1)', '   pH', ' N', ' P', ' K', '   O', ' Ca', ' Mg',
#        ' Cu', ' Fe', '  Zn', 'Soil Fertility Status', 'Crop Recommendation 1',
#        'Crop Recommendation 2', 'Fertilizer Recommendation 1',
#        'Fertilizer Recommendation 2'],
#       dtype='object')

# %%
# Assuming you have a DataFrame named df
df_clean.columns = df_clean.columns.str.lower().str.replace(' ', '').str.strip()

# Print the cleaned column names
print(df_clean.columns)
# Out:
# Index(['simpliedtexture(1)', 'ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe',
#        'zn', 'soilfertilitystatus', 'croprecommendation1',
#        'croprecommendation2', 'fertilizerrecommendation1',
#        'fertilizerrecommendation2'],
#       dtype='object')

# %% [markdown]
# #### 4. Checking for Validity

# %%
# statistical summary for the dataset
df_clean.describe()
# Out:
#                 ph            n            p            k            o  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      5.663500     0.185450    24.676900     0.944160     1.231500
# std       0.581322     0.725878     4.176681     0.284115     0.711213
# min       4.000000     0.080000    16.900000     0.060000     0.200000
# 25%       5.200000     0.140000    20.800000     1.030000     0.900000
# 50%       5.600000     0.170000    23.700000     1.070000     1.000000
# 75%       6.000000     0.170000    28.300000     1.070000     1.500000
# max       9.100000    23.100000    38.500000     1.220000    15.400000
#
#                 ca           mg           cu           fe           zn
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.567600     1.722800     1.394300    11.769500     6.018800
# std       1.626012     0.462465     0.194565     0.881224     1.711513
# min       0.800000     0.800000     0.700000    10.100000     3.700000
# 25%       1.300000     1.200000     1.200000    11.200000     4.700000
# 50%       2.200000     1.800000     1.500000    12.200000     5.600000
# 75%       3.300000     2.100000     1.500000    12.500000     7.400000
# max      11.300000     3.100000     1.900000    13.100000    10.300000

# %%
# Create a figure with a specified size
plt.figure(figsize=(12, 8))

# Create a boxplot for all numeric columns in the dataset
df_clean.boxplot(patch_artist=True, boxprops=dict(facecolor='lightblue', color='blue'),
             medianprops=dict(color='red'), whiskerprops=dict(color='blue'),
             capprops=dict(color='blue'), flierprops=dict(marker='o', color='blue', alpha=0.5))

# Add a title and labels for the axes
plt.title("Boxplot of All Numeric Columns", fontsize=18)
plt.xlabel("Columns", fontsize=15)
plt.ylabel("Values", fontsize=15)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0, fontsize=12)

# Add grid lines for better readability
plt.grid(True)

# Display the plot
plt.show()

# %%
def check_outliers(df):
    # List to store outlier details for each column
    outlier_data = []

    # Loop through numeric columns
    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        # Compute Q1, Q3, and IQR
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        # Compute outlier boundaries
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Count outliers
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_count = outliers.shape[0]
        outlier_percentage = (outlier_count / df.shape[0]) * 100

        # Append details to the list
        outlier_data.append({
            'column': col,
            'outlier_count': outlier_count,
            'outlier_percentage': outlier_percentage,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound
        })

    # Convert list to DataFrame
    outlier_df = pd.DataFrame(outlier_data)
    return outlier_df

# %%
check_outliers(df_clean)
# Out:
#   column  outlier_count  outlier_percentage   lower_bound  upper_bound
# 0     ph             16                 1.6  4.000000e+00        7.200
# 1      n             62                 6.2  9.500000e-02        0.215
# 2      p              0                 0.0  9.550000e+00       39.550
# 3      k            301                30.1  9.700000e-01        1.130
# 4      o              4                 0.4  1.110223e-16        2.400
# 5     ca             28                 2.8 -1.700000e+00        6.300
# 6     mg              0                 0.0 -1.500000e-01        3.450
# 7     cu             10                 1.0  7.500000e-01        1.950
# 8     fe              0                 0.0  9.250000e+00       14.450
# 9     zn              0                 0.0  6.500000e-01       11.450

# %% [markdown]
# The analysis show presence of outliers in the dataset more so on the Potassium column(K) with 30.1 % outlier values

# %% [markdown]
# ### Explanatory Data Analysis

# %%
# histogram of the dataset
df_clean.hist(figsize=(20, 20))

plt.show()

# %% [markdown]
# #### 1. Univariate Analyis

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['soilfertilitystatus'], ax=ax, palette='Set2')

plt.title("Distribution of the Soil Fertility Status", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Soil Fertility Status", fontsize=14)

plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_fertility_status_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/3742994308.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['soilfertilitystatus'], ax=ax, palette='Set2')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['simpliedtexture(1)'], ax=ax, palette='Set2')

plt.title("Distribution of the Simplied soil Texture (1)", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Simplied soil Texture", fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_texture_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/1338068663.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['simpliedtexture(1)'], ax=ax, palette='Set2')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['croprecommendation1'], ax=ax, palette='viridis')

plt.title("Distribution of Crop Recommendation 1", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Crop Recommendation 1", fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/crop_recommendation_1_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/824741115.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['croprecommendation1'], ax=ax, palette='viridis')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['croprecommendation2'], ax=ax, palette='viridis')

plt.title("Distribution of Crop Recommendation 2", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Crop Recommendation 2", fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/Crop Recommendation 2_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/4205834284.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['croprecommendation2'], ax=ax, palette='viridis')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['fertilizerrecommendation1'], ax=ax, palette='magma')

plt.title("Distribution of Fertilizer Recommendation 1)", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Fertilizer Recommendation 1", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/fertilizer_recommendation_1_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/3245676672.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['fertilizerrecommendation1'], ax=ax, palette='magma')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x=df_clean['fertilizerrecommendation2'], ax=ax, palette='viridis')

plt.title("Distribution of Fertilizer Recommendation 2", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Fertilizer Recommendation 2", fontsize=14)

plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/fertilizer_recommendation_2_plot.png'
plt.savefig(plot_path, dpi=300)

plt.show()
# Out:
# /var/folders/k3/6rk4z8696pz8g275b3dtg8kh0000gn/T/ipykernel_28245/3230084628.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_clean['fertilizerrecommendation2'], ax=ax, palette='viridis')

# %% [markdown]
# #### 2. Bivariate Analysis

# %%
# The relationship between Soil Fertility Status and Crop Recommendation 1

fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x='soilfertilitystatus', hue='croprecommendation1', data=df_clean, palette='Set2', ax=ax)

plt.title("Soil Fertility Status vs Crop Recommendation 1", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Soil Fertility Status", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_fertility_vs_crop_recommendation_1.png'
plt.savefig(plot_path, dpi=300) 

plt.show()

# %%
# The relationship between Soil Fertility Status and Crop Recommendation 2

fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x='soilfertilitystatus', hue='croprecommendation2', data=df_clean, palette='Set2', ax=ax)

plt.title("Soil Fertility Status vs Crop Recommendation 2", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Soil Fertility Status", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_fertility_vs_crop_recommendation_2.png'
plt.savefig(plot_path, dpi=300) 

plt.show()

# %%
# The relationship between Soil Fertility Status and Crop Recommendation 1

fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x='soilfertilitystatus', hue='fertilizerrecommendation2', data=df_clean, palette='viridis', ax=ax)

plt.title("Soil Fertility Status vs Fertilizer Recommendation 2", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Soil Fertility Status", fontsize=14)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_fertility_vs_crop_recommendation_1.png'
plt.savefig(plot_path, dpi=300) 

plt.show()

# %%
# The relationship between Soil Fertility Status and Crop Recommendation 1

fig, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x='soilfertilitystatus', hue='fertilizerrecommendation1', data=df_clean, palette='viridis', ax=ax)

plt.title("Soil Fertility Status vs Fertilizer Recommendation 1", fontsize=16)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Soil Fertility Status", fontsize=14)

plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

# Saving the plot with higher resolution
plot_path = '../eda_charts/soil_fertility_vs_crop_recommendation_1.png'
plt.savefig(plot_path, dpi=300) 

plt.show()

# %% [markdown]
# #### 3. Multivariate Analysis

# %%
# Ensure df_clean contains only numerical data
df_clean_numeric = df_clean.select_dtypes(include=['number'])

# Compute the correlation matrix if needed
correlation_matrix = df_clean_numeric.corr()

# %%
# Plot the heatmap
fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='viridis', ax=ax, linewidths=0.5)

plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=0, ha='right', fontsize=12)
plt.yticks(fontsize=12)

# Saving the heatmap with higher resolution
heatmap_path = '../eda_charts/soil_correlation_heatmap.png'
plt.savefig(heatmap_path, dpi=300)

plt.show()

# %% [markdown]
# ### Data Preparation

# %%
# %pip install imblearn

# %%
# Importing necessary libraries for preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# %% [markdown]
# #### 1. Encoding Categorical Columns

# %%
# Encoding categorical values
def encode_categorical_columns(df: pd.DataFrame, encoding_type: str = 'label') -> pd.DataFrame:
    """
    Encodes categorical columns in a DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame with categorical columns.
        encoding_type (str): The encoding type, either 'label' or 'onehot'.

    Returns:
        pd.DataFrame: A DataFrame with encoded categorical columns.
    """

    df_encoded = df.copy()

    categorical_columns = df_encoded.select_dtypes(include=['category']).columns

    if encoding_type == 'label':
        for col in categorical_columns:
            le = LabelEncoder()
            df_encoded[col] = le.fit_transform(df_encoded[col])

    elif encoding_type == 'onehot':
        df_encoded = pd.get_dummies(df_encoded, columns=categorical_columns, drop_first=True)
    else:
        raise ValueError("Unsupported encoding_type. Use 'label' or 'onehot' .")


    return df_encoded

# %%
# Preview of data before encoding
df_clean.sample(5)
# Out:
#     simpliedtexture(1)   ph     n     p     k    o   ca   mg   cu    fe   zn  \
# 46                LOAM  5.2  0.11  22.9  1.07  1.1  1.7  1.9  1.5  10.3  7.4
# 877         LOAMY SOIL  5.5  0.17  29.2  1.03  1.7  2.5  1.3  1.5  12.5  4.2
# 187         SANDY SILT  5.1  0.14  22.7  1.07  1.1  3.2  1.8  1.5  10.3  4.9
# 122               LOAM  5.6  0.15  27.7  1.07  1.1  2.9  1.2  1.2  12.5  5.4
# 73                LOAM  5.7  0.17  27.1  1.17  1.7  4.1  1.9  1.5  10.2  4.3
#
#     soilfertilitystatus croprecommendation1 croprecommendation2  \
# 46                 POOR             SOYBEAN              SESAME
# 877                POOR             SOYBEAN              SESAME
# 187                POOR              SESAME             SOYBEAN
# 122                POOR             SORGHUM              MILLET
# 73   MODERATELY HEALTHY               MAIZE               BEANS
#
#     fertilizerrecommendation1 fertilizerrecommendation2
# 46                        NPK                       NPK
# 877                       NPK                       NPK
# 187                       NPK                       NPK
# 122                       NPK                       NPK
# 73                        NPK                       TSP

# %%
# encoding the categorical columns

df_encoded = encode_categorical_columns(df_clean, encoding_type='label')
df_encoded.sample(5)
# Out:
#      simpliedtexture(1)   ph     n     p     k    o    ca   mg   cu    fe  \
# 539                   9  6.6  0.24  22.2  1.07  1.2  11.3  2.1  1.3  10.3
# 74                   18  5.6  0.15  27.1  1.07  1.4   2.4  2.8  1.1  10.5
# 868                   9  5.8  0.17  29.3  1.07  0.9   3.3  1.7  1.2  12.2
# 635                   8  5.6  0.14  19.8  1.07  1.1   2.9  1.8  1.4  11.2
# 442                   9  5.7  0.17  31.1  1.07  1.0   1.2  1.2  1.5  12.7
#
#       zn  soilfertilitystatus  croprecommendation1  croprecommendation2  \
# 539  5.9                    0                    1                    1
# 74   9.4                    1                   11                    9
# 868  4.2                    0                   16                   10
# 635  7.4                    1                   16                   10
# 442  7.4                    0                    8                    3
#
#      fertilizerrecommendation1  fertilizerrecommendation2
# 539                          0                          0
# 74                           0                          0
# 868                          0                          0
# 635                          0                          0
# 442                          0                          1

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   simpliedtexture(1)         1000 non-null   int64
#  1   ph                         1000 non-null   float64
#  2   n                          1000 non-null   float64
#  3   p                          1000 non-null   float64
#  4   k                          1000 non-null   float64
#  5   o                          1000 non-null   float64
#  6   ca                         1000 non-null   float64
#  7   mg                         1000 non-null   float64
#  8   cu                         1000 non-null   float64
#  9   fe                         1000 non-null   float64
#  10  zn                         1000 non-null   float64
#  11  soilfertilitystatus        1000 non-null   int64
#  12  croprecommendation1        1000 non-null   int64
#  13  croprecommendation2        1000 non-null   int64
#  14  fertilizerrecommendation1  1000 non-null   int64
#  15  fertilizerrecommendation2  1000 non-null   int64
# dtypes: float64(10), int64(6)
# memory usage: 125.1 KB

# %%
df_clean['soilfertilitystatus'].value_counts()
# Out:
# soilfertilitystatus
# MODERATELY HEALTHY    493
# POOR                  377
# VERY POOR             130
# Name: count, dtype: int64

# %%
#df_encoded['soilfertilitystatus'].value_counts()

# %% [markdown]
# #### 2. Scaling the values

# %%
# scaling the values

def scale_dataset(df: pd.DataFrame,target_column : str , scaling_type: str = 'standard') -> pd.DataFrame:
    """
    Scales numerical columns in the DataFrame.

    Parameters:
        df (pd.DataFrame): The input DataFrame.
        scaling_type (str): The type of scaling to apply, either 'standard' or 'minmax'.

    Returns:
        pd.DataFrame: A DataFrame with scaled numerical columns.
    """
    df_scaled = df.copy()

    # select numeric columns
    numerical_columns = df_scaled.select_dtypes(include=['float64']).columns
    columns_to_scale = numerical_columns.difference([target_column])

    if scaling_type == 'standard':
        scaler = StandardScaler()
    elif scaling_type == 'minmax':
        scaler = MinMaxScaler()
    else:
        raise ValueError("Unsupported scaling_type. Use 'standard' or 'minmax'. ")

    df_scaled[columns_to_scale] = scaler.fit_transform(df_scaled[columns_to_scale])

    return df_scaled

# %%
# Preview of data before scaling
df_encoded.sample(5)
# Out:
#      simpliedtexture(1)   ph     n     p     k    o   ca   mg   cu    fe   zn  \
# 108                   3  5.7  0.17  22.1  1.09  1.5  0.9  1.8  1.2  12.7  7.5
# 263                   7  4.9  0.14  29.4  1.10  1.8  1.7  2.2  1.5  12.5  6.3
# 87                    3  5.1  0.13  28.0  1.07  0.4  0.9  2.1  1.5  11.9  4.3
# 0                    19  4.9  0.14  22.9  0.14  1.1  1.3  2.2  1.2  10.1  5.6
# 282                   7  5.0  0.14  17.7  1.07  1.0  1.2  1.9  1.5  12.7  3.9
#
#      soilfertilitystatus  croprecommendation1  croprecommendation2  \
# 108                    0                    1                    1
# 263                    2                    6                    5
# 87                     1                   13                   12
# 0                      2                    6                    5
# 282                    2                   16                   10
#
#      fertilizerrecommendation1  fertilizerrecommendation2
# 108                          0                          0
# 263                          0                          0
# 87                           0                          0
# 0                            0                          0
# 282                          0                          0

# %%
# scaling the dataset
df_scaled = scale_dataset(df_encoded, scaling_type = 'standard', target_column = 'soilfertilitystatus')
df_scaled.sample(5)
# Out:
#      simpliedtexture(1)        ph          n         p         k         o  \
# 789                   9 -0.453504   0.006271 -0.305874 -0.789372 -0.747689
# 935                   9  0.751250  -0.007512 -1.168234 -0.049864  1.362440
# 647                   9 -0.109288  -0.048862  0.604394  0.443141 -0.044313
# 125                  10  0.751250   0.061405 -0.569373  0.443141  0.799739
# 731                   5 -0.453504  31.583841 -0.593327  0.548785 -0.325663
#
#            ca        mg        cu        fe        zn  soilfertilitystatus  \
# 789 -0.533842  1.032378  0.543536  0.488769  1.333523                    1
# 935  1.435148 -1.131029  0.543536  1.056446 -1.238589                    0
# 647  0.450653 -1.347370  0.543536 -0.987189 -1.063217                    1
# 125  1.496679 -1.347370  0.543536  0.488769 -0.946303                    0
# 731  0.450653  0.599696 -2.541816  1.056446 -0.186361                    1
#
#      croprecommendation1  croprecommendation2  fertilizerrecommendation1  \
# 789                   14                    7                          0
# 935                    8                    3                          0
# 647                   16                   10                          0
# 125                    1                    1                          0
# 731                   13                   12                          0
#
#      fertilizerrecommendation2
# 789                          0
# 935                          1
# 647                          0
# 125                          0
# 731                          0

# %% [markdown]
# #### 3. Class balancing of the target column

# %%
df_clean['soilfertilitystatus'].value_counts()
# Out:
# soilfertilitystatus
# MODERATELY HEALTHY    493
# POOR                  377
# VERY POOR             130
# Name: count, dtype: int64

# %%
df_scaled['soilfertilitystatus'].value_counts()
# Out:
# soilfertilitystatus
# 0    493
# 1    377
# 2    130
# Name: count, dtype: int64

# %%
# checking for class imbalance

def balance_with_smote(df: pd.DataFrame, target_column: str):
    """
    Apply SMOTE to balance the dataset.

    Parameters:
        df (pd.DataFrame): Input DataFrame (encoded and scaled).
        target_column (str): Name of the target column.

    Returns:
        X_resampled (pd.DataFrame): Resampled feature set.
        y_resampled (pd.Series): Resampled target column.
    """
    X = df.drop(columns=[target_column])
    y = df[target_column]

    smote = SMOTE(random_state=142)
    X_resampled, y_resampled = smote.fit_resample(X, y)

    # Convert back to DataFrame
    X_resampled = pd.DataFrame(X_resampled, columns=X.columns)
    y_resampled = pd.Series(y_resampled, name=target_column)

    return X_resampled, y_resampled

# %%
df_clean.columns
# Out:
# Index(['Simplied Texture (1)', '   pH', ' N', ' P', ' K', '   O', ' Ca', ' Mg',
#        ' Cu', ' Fe', '  Zn', 'Soil Fertility Status', 'Crop Recommendation 1',
#        'Crop Recommendation 2', 'Fertilizer Recommendation 1',
#        'Fertilizer Recommendation 2'],
#       dtype='object')

# %%
df_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Simplied Texture (1)         1000 non-null   int64
#  1      pH                        1000 non-null   float64
#  2    N                           1000 non-null   float64
#  3    P                           1000 non-null   float64
#  4    K                           1000 non-null   float64
#  5      O                         1000 non-null   float64
#  6    Ca                          1000 non-null   float64
#  7    Mg                          1000 non-null   float64
#  8    Cu                          1000 non-null   float64
#  9    Fe                          1000 non-null   float64
#  10    Zn                         1000 non-null   float64
#  11  Soil Fertility Status        1000 non-null   int64
#  12  Crop Recommendation 1        1000 non-null   int64
#  13  Crop Recommendation 2        1000 non-null   int64
#  14  Fertilizer Recommendation 1  1000 non-null   int64
#  15  Fertilizer Recommendation 2  1000 non-null   int64
# dtypes: float64(10), int64(6)
# memory usage: 125.1 KB

# %%
df_scaled.columns
# Out:
# Index(['simpliedtexture(1)', 'ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe',
#        'zn', 'soilfertilitystatus', 'croprecommendation1',
#        'croprecommendation2', 'fertilizerrecommendation1',
#        'fertilizerrecommendation2'],
#       dtype='object')

# %%
# Saving the dataset after the preprocessing step to use it to model the fertilizer classifier
df_clean.to_csv("../data/data_for_fertilizer_classification.csv", index=False)

# %% [markdown]
# ### Preprocessing and saving the preprocessed file

# %%
# DROP unecessary columns first

df_clean = df_clean.drop(columns=['croprecommendation1', 'croprecommendation2', 'fertilizerrecommendation1', 'fertilizerrecommendation2' ])
df_clean.columns
# Out:
# Index(['simpliedtexture(1)', 'ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe',
#        'zn', 'soilfertilitystatus'],
#       dtype='object')

# %%
df_clean.head()
# Out:
#   simpliedtexture(1)   ph     n     p     k    o   ca   mg   cu    fe   zn  \
# 0         SILTY SOIL  4.9  0.14  22.9  0.14  1.1  1.3  2.2  1.2  10.1  5.6
# 1         LOAMY SOIL  5.7  0.14  28.3  0.27  1.3  1.8  2.1  1.2  12.9  5.2
# 2         SILTY LOAM  5.9  0.16  23.1  0.39  2.1  1.6  2.5  1.2  10.1  6.4
# 3         LOAMY SOIL  5.7  0.20  29.2  0.47  2.1  2.8  2.2  1.2  12.0  7.4
# 4               LOAM  5.7  0.14  28.3  0.28  2.2  3.2  1.4  1.2  12.3  7.0
#
#   soilfertilitystatus
# 0           VERY POOR
# 1  MODERATELY HEALTHY
# 2  MODERATELY HEALTHY
# 3  MODERATELY HEALTHY
# 4  MODERATELY HEALTHY

# %%
from api.preprocessing import SoilDataPreprocessor

# %%
# During training phase
preprocessor = SoilDataPreprocessor()

# Fit and transform training data
train_data_processed = preprocessor.fit_transform(
    df_clean, 
    target_column='soilfertilitystatus',
    encoding_type='label',
    scaling_type='standard',
    apply_smote=False
)
# Out:
# 2025-05-28 21:42:28,569 - SoilDataPreprocessor - INFO - SoilDataPreprocessor initialized
# 2025-05-28 21:42:28,572 - SoilDataPreprocessor - INFO - ============================================================
# 2025-05-28 21:42:28,574 - SoilDataPreprocessor - INFO - Starting fit_transform process
# 2025-05-28 21:42:28,576 - SoilDataPreprocessor - INFO - Parameters - encoding: label, scaling: standard, SMOTE: False
# 2025-05-28 21:42:28,578 - SoilDataPreprocessor - INFO - Input DataFrame shape: (1000, 12)
# 2025-05-28 21:42:28,580 - SoilDataPreprocessor - INFO - Target column: soilfertilitystatus
# 2025-05-28 21:42:28,581 - SoilDataPreprocessor - INFO - Target column data type: category
# 2025-05-28 21:42:28,586 - SoilDataPreprocessor - INFO - Target classes: ['VERY POOR', 'MODERATELY HEALTHY', 'POOR']
# Categories (3, object): ['MODERATELY HEALTHY', 'POOR', 'VERY POOR']
# 2025-05-28 21:42:28,587 - SoilDataPreprocessor - INFO - ----------------------------------------
# 2025-05-28 21:42:28,589 - SoilDataPreprocessor - INFO - STEP 1: Categorical Encoding
# 2025-05-28 21:42:28,591 - SoilDataPreprocessor - INFO - Starting categorical encoding with type: label
# 2025-05-28 21:42:28,595 - SoilDataPreprocessor - INFO - Found 2 categorical columns: ['simpliedtexture(1)', 'soilfertilitystatus']
# 2025-05-28 21:42:28,602 - SoilDataPreprocessor - INFO - Fitted LabelEncoder for simpliedtexture(1), classes: 20
# 2025-05-28 21:42:28,606 - SoilDataPreprocessor - INFO - Fitted LabelEncoder for soilfertilitystatus, classes: 3
# 2025-05-28 21:42:28,608 - SoilDataPreprocessor - INFO - Categorical encoding completed. Output shape: (1000, 12)
# 2025-05-28 21:42:28,609 - SoilDataPreprocessor - INFO - ----------------------------------------
# 2025-05-28 21:42:28,609 - SoilDataPreprocessor - INFO - STEP 2: Numerical Scaling
# 2025-05-28 21:42:28,610 - SoilDataPreprocessor - INFO - Starting numerical scaling with type: standard
# 2025-05-28 21:42:28,614 - SoilDataPreprocessor - INFO - Found 10 numerical columns: ['ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe', 'zn']
# 2025-05-28 21:42:28,615 - SoilDataPreprocessor - INFO - Columns to scale: ['ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe', 'zn']
# 2025-05-28 21:42:28,616 - SoilDataPreprocessor - INFO - Fitting scaler (training mode)
# 2025-05-28 21:42:28,634 - SoilDataPreprocessor - INFO - Scaler fitted and applied to 10 columns
# 2025-05-28 21:42:28,637 - SoilDataPreprocessor - INFO - Numerical scaling completed. Output shape: (1000, 12)
# 2025-05-28 21:42:28,639 - SoilDataPreprocessor - INFO - Preprocessor marked as fitted
# 2025-05-28 21:42:28,640 - SoilDataPreprocessor - INFO - ============================================================
# 2025-05-28 21:42:28,641 - SoilDataPreprocessor - INFO - fit_transform completed successfully. Final shape: (1000, 12)

# %%
# saving the preprocessor
preprocessor.save('models/soil_fertility_status_preprocessor.joblib')
# Out:
# 2025-05-28 21:42:34,577 - SoilDataPreprocessor - INFO - Saving preprocessor to: models/soil_fertility_status_preprocessor.joblib
# 2025-05-28 21:42:34,588 - SoilDataPreprocessor - INFO - Preprocessor saved successfully

# %%
train_data_processed.sample(10)
# Out:
#      simpliedtexture(1)        ph         n         p         k         o  \
# 485                   9  1.783896 -0.021295 -0.234011  0.302283  0.659064
# 936                   9  0.407035 -0.062645  0.939757  0.443141  0.799739
# 321                   9  1.095465 -0.007512  1.538618 -2.831822 -0.466338
# 935                   9  0.751250 -0.007512 -1.168234 -0.049864  1.362440
# 147                  12 -0.453504 -0.076428 -0.617282  0.443141 -0.466338
# 620                   9 -0.797719 -0.062645 -0.449601 -0.789372  1.081089
# 580                   9  0.579142 -0.007512  0.796030  0.443141 -0.044313
# 156                  12 -0.109288 -0.062645 -0.449601  0.443141 -0.466338
# 967                   9  0.234927 -0.062645  1.083483  0.443141 -0.466338
# 833                   5 -0.969827 -0.021295 -0.617282  0.443141 -0.044313
#
#            ca        mg        cu        fe        zn  soilfertilitystatus
# 485 -0.041595 -0.914688  0.543536  0.829375 -0.770932                    0
# 936  1.496679 -1.347370  0.543536  0.488769 -1.004760                    0
# 321 -0.841497  1.032378 -0.999140 -1.895471  0.222838                    0
# 935  1.435148 -1.131029  0.543536  1.056446 -1.238589                    0
# 147 -0.903028 -1.131029  0.543536 -1.668401  0.164381                    1
# 620  1.127493  0.383356 -0.999140 -0.646583 -0.303275                    1
# 580  0.881369  0.816037  0.543536  0.488769  0.164381                    0
# 156  0.019936  0.167015  0.543536  0.488769  0.164381                    1
# 967  0.019936  0.167015  0.543536  0.488769  0.807409                    0
# 833  5.373128  0.816037 -0.484915 -1.668401  1.976551                    1

# %%
from sklearn.model_selection import train_test_split

X = train_data_processed.drop(columns=['soilfertilitystatus'])
y = train_data_processed['soilfertilitystatus']

print(f"X columns used: \n", X.columns)
print(f"\ny target columns:", y.name)

# splitting the dataset into train , test and validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=43)
# Out:
# X columns used:
#  Index(['simpliedtexture(1)', 'ph', 'n', 'p', 'k', 'o', 'ca', 'mg', 'cu', 'fe',
#        'zn'],
#       dtype='object')
#
# y target columns: soilfertilitystatus

# %% [markdown]
# ### Modelling

# %%
# %pip install xgboost

# %%
# Model libraries
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# model metrics libraries

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %% [markdown]
# #### 1. Baseline Model

# %%
# OneVsRestClassifier with LinearSVC 

# Initialize the OneVsRestClassifier with LinearSVC
OvR_clf = OneVsRestClassifier(LinearSVC(random_state=42, dual=False, max_iter=5000))

# Fit the model on the training data
OvR_clf.fit(X_train, y_train)

# Predict on the test data
y_pred_ovr_clf = OvR_clf.predict(X_test)

# %%
# Model Evaluation for Logistic Regression
print("Multiclass with OneVsRest:")

# Accuracy is the ratio of correctly predicted observation to the total observations.
print(f"Accuracy: {accuracy_score(y_test, y_pred_ovr_clf):.4f}")

# Precision is the ratio of correctly predicted positive observations to the total predicted positives.
print(f"Precision: {precision_score(y_test, y_pred_ovr_clf, average='macro'):.4f}")

# Recall (Sensitivity) is the ratio of correctly predicted positive observations to the all observations in actual class.
print(f"Recall: {recall_score(y_test, y_pred_ovr_clf, average='macro'):.4f}")

# F1 Score is the weighted average of Precision and Recall. Therefore, this score takes both false positives and false negatives into account.
print(f"F1 Score: {f1_score(y_test, y_pred_ovr_clf, average='macro'):.4f}")
# Out:
# Multiclass with OneVsRest:
# Accuracy: 0.9480
# Precision: 0.9627
# Recall: 0.9117
# F1 Score: 0.9345

# %%
print("Classification report:\n", classification_report(y_test, y_pred_ovr_clf))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       143
#            1       0.95      0.89      0.92        81
#            2       1.00      0.85      0.92        26
#
#     accuracy                           0.95       250
#    macro avg       0.96      0.91      0.93       250
# weighted avg       0.95      0.95      0.95       250

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_ovr_clf, labels=OvR_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=OvR_clf.classes_)
disp.plot(cmap='Greens')
plt.xticks(rotation=90)

# Saving the plot
plot_path = 'eda_charts/models_evals/one_versus_rest_confusion_matrix.png'
plt.savefig(plot_path)

# %%
# Save the model to a file
import joblib

joblib.dump(OvR_clf, 'models/Soil_Status_OneVsRest_Classifier_model.joblib')
print("OneVsRestClassifier models saved to: models/Soil_Status_OneVsRest_Classifier_model")
# Out:
# OneVsRestClassifier models saved to: models/Soil_Status_OneVsRest_Classifier_model

# %% [markdown]
# #### 2. Decision Tree Models

# %%
# decision trees
from sklearn.tree import DecisionTreeClassifier

# Initialize the Decision Tree Classifier
dtree = DecisionTreeClassifier()

# Fit the model on the training data
dtree.fit(X_train, y_train)

# Predict on the test data
y_pred_tree = dtree.predict(X_test)

# %%
print("Multiclass with Decision tree classifier:")

# Accuracy is the proportion of true results (both true positives and true negatives) among the total number of cases examined.
print(f"Accuracy: {accuracy_score(y_test, y_pred_tree):.4f}")

# Precision is the ratio of correctly predicted positive observations to the total predicted positives.
print(f"Precision: {precision_score(y_test, y_pred_tree, average='macro'):.4f}")

# Recall (Sensitivity) is the ratio of correctly predicted positive observations to the all observations in actual class.
print(f"Recall: {recall_score(y_test, y_pred_tree, average='macro'):.4f}")

# F1 Score is the weighted average of Precision and Recall.
print(f"F1 Score: {f1_score(y_test, y_pred_tree, average='macro'):.4f}")
# Out:
# Multiclass with Decision tree classifier:
# Accuracy: 0.9880
# Precision: 0.9912
# Recall: 0.9894
# F1 Score: 0.9903

# %%
print("Classification report:\n", classification_report(y_test, y_pred_tree))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       143
#            1       0.99      0.98      0.98        81
#            2       1.00      1.00      1.00        26
#
#     accuracy                           0.99       250
#    macro avg       0.99      0.99      0.99       250
# weighted avg       0.99      0.99      0.99       250

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_tree, labels=dtree.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dtree.classes_)
disp.plot(cmap='Greens')
plt.xticks(rotation=90)

# Saving the plot
plot_path = 'eda_charts/models_evals/decision_tree_confusion_matrix.png'
plt.savefig(plot_path)

plt.show()

# %%
# Save the model to a file
joblib.dump(dtree, 'models/Soil_Status_decisionTree_Classifier_model.joblib')

print("Decision Tree Classifier models saved to: models/Soil_Status_decisionTree_Classifier_model")
# Out:
# Decision Tree Classifier models saved to: models/Soil_Status_decisionTree_Classifier_model

# %% [markdown]
# #### 3. Random Forest Classifier

# %%
# Random forest classifier

# Initialize the Random Forest Classifier
rf = RandomForestClassifier(random_state=142)

# Fit the model
rf.fit(X_train, y_train)

# Make predictions on test set
y_pred_rf = rf.predict(X_test)

# %%
# Model Evaluation for Random Forest
print("\nRandom Forest:")

# Accuracy is the proportion of true results (both true positives and true negatives) among the total number of cases examined.
print(f"Accuracy: {accuracy_score(y_test, y_pred_rf)}")

# Precision is the ratio of correctly predicted positive observations to the total predicted positives.
print(f"Precision: {precision_score(y_test, y_pred_rf, average='macro'):.4f}")

# Recall (Sensitivity) is the ratio of correctly predicted positive observations to the all observations in actual class.
print(f"Recall: {recall_score(y_test, y_pred_rf, average='macro'):.4f}")

# F1 Score is the weighted average of Precision and Recall. It tries to find the balance between precision and recall.
print(f"F1 Score: {f1_score(y_test, y_pred_rf, average='macro'):.4f}")
# Out:
# Random Forest:
# Accuracy: 0.996
# Precision: 0.9959
# Recall: 0.9977
# F1 Score: 0.9968

# %%
print("Classification report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       143
#            1       0.99      1.00      0.99        81
#            2       1.00      1.00      1.00        26
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_rf, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf.classes_)
disp.plot(cmap='Greens')
plt.xticks(rotation=90)

# Saving the plot
plot_path = 'eda_charts/models_evals/random_forest_confusion_matrix.png'
plt.savefig(plot_path)

plt.show()

# %%
# Save the model to a file
joblib.dump(rf, "models/Soil_Status_randomForest_Classifier_Model.joblib")

print("Random Forest Classifier saved to: models/Soil_Status_randomForest_Classifier")
# Out:
# Random Forest Classifier saved to: models/Soil_Status_randomForest_Classifier

# %% [markdown]
# #### 4. Gradient Boosting Machine

# %%
from xgboost import XGBClassifier

# %%
# xg boost

# initialise the model
xgb = XGBClassifier(random_state=142)

# Fit the model
xgb.fit(X_train, y_train)

# predict the test set
y_pred_xgb = xgb.predict(X_test)

# %%
# Model Evaluation for XGBoost
print("\nGradient Boosting Machine (XGBoost):")

# Accuracy is the proportion of true results (both true positives and true negatives) among the total number of cases examined.
print(f"Accuracy: {accuracy_score(y_test, y_pred_xgb):.4f}")

# Precision is the ratio of correctly predicted positive observations to the total predicted positives.
print(f"Precision: {precision_score(y_test, y_pred_xgb, average='macro'):.4f}")

# Recall (Sensitivity) is the ratio of correctly predicted positive observations to the all observations in actual class.
print(f"Recall: {recall_score(y_test, y_pred_xgb, average='macro'):.4f}")

# F1 Score is the weighted average of Precision and Recall. It tries to find the balance between precision and recall.
print(f"F1 Score: {f1_score(y_test, y_pred_xgb, average='macro'):.4f}")
# Out:
# Gradient Boosting Machine (XGBoost):
# Accuracy: 0.9960
# Precision: 0.9959
# Recall: 0.9977
# F1 Score: 0.9968

# %%
print("Classification report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       143
#            1       0.99      1.00      0.99        81
#            2       1.00      1.00      1.00        26
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_xgb, labels=xgb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgb.classes_)
disp.plot(cmap='Greens')
plt.xticks(rotation=90)

# Saving the plot
plot_path = 'eda_charts/models_evals/xgboost_confusion_matrix.png'
plt.savefig(plot_path)

plt.show()

# %%
# Save the model to a file
joblib.dump(rf, "models/Soil_Status_xgb_Model.joblib")

print("Gradient Boosting Classifier saved to: models/Soil_Status_xgb_Classifier")
# Out:
# Gradient Boosting Classifier saved to: models/Soil_Status_xgb_Classifier
